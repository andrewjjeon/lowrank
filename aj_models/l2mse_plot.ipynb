# %%
# %matplotlib inline
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['figure.dpi'] = 200
import matplotlib.colors as colors
import torch
import torch.nn as nn
import torch.optim as optim
import copy
import numpy.linalg as la
import os
from sklearn.metrics import r2_score, roc_auc_score
from torch.utils.data import Dataset, DataLoader, Subset
from torch.optim.lr_scheduler import StepLR
from pathlib import Path

# %%
l2_lambdas = [1e-7, 1e-6, 1e-5, 1e-4]
mses = [0.000504, 0.000264, 0.000268, 0.000395]

plt.figure(figsize=(12,6), dpi=80)
plt.plot(l2_lambdas, mses, marker='o', linestyle='-', color='b')


plt.title("L2 Reg Effect on MSE of Full Rank @ 100 epochs")
plt.xlabel("l2 lambda values")
plt.ylabel("MSE")

# Set x-axis ticks
plt.xscale('log')
plt.xticks([1e-7, 1e-6, 1e-5, 1e-4])

plt.grid(True, which='both', linestyle='--', linewidth=0.7)
plt.legend()
plt.show()





l2s = [1e-7, 1e-6, 1e-5]
msess = [0.000343, 0.000241, 0.000266]

plt.figure(figsize=(12,6), dpi=80)
plt.plot(l2s, msess, marker='o', linestyle='-', color='b')


plt.title("L2 Reg Effect on MSE of Full Rank @ 100 epochs")
plt.xlabel("l2 lambda values")
plt.ylabel("MSE")

# Set x-axis ticks
plt.xscale('log')
plt.xticks([1e-7, 1e-6, 1e-5])

plt.grid(True, which='both', linestyle='--', linewidth=0.7)
plt.legend()
plt.show()

# fifty_mses = [0.014202663127614043, 0.00027289830347368687, 0.0003331103308068345, 0.00033262420334919155, 0.00033275339915506526]

# plt.figure(figsize=(12,6), dpi=80)
# plt.plot(l2_lambdas, fifty_mses, marker='o', linestyle='-', color='r')

# plt.title("L2 Reg Effect on MSE of Low-Rank 35 models @ 50 epochs")
# plt.xlabel("l2 lambda values")
# plt.ylabel("MSE")

# # Set x-axis ticks
# plt.xscale('log')
# plt.xticks([0.0001, 0.001, 0.01, 0.1])
# plt.yticks([0.00027, 0.00033, 0.0142])
# plt.grid(True, which='both', linestyle='--', linewidth=0.7)
# plt.legend()
# plt.show()
